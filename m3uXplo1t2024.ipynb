# %%
# !wget https://github.com/xylozd/te/raw/main/API_MAC_SCANNER_FINAL.py
# !wget https://github.com/xylozd/te/raw/main/XPLOITFUNCIONAL2024.py
# Out:
# --2024-06-28 06:57:43--  https://github.com/xylozd/te/raw/main/API_MAC_SCANNER_FINAL.py
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/xylozd/te/main/API_MAC_SCANNER_FINAL.py [following]
# --2024-06-28 06:57:43--  https://raw.githubusercontent.com/xylozd/te/main/API_MAC_SCANNER_FINAL.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 97462 (95K) [text/plain]
# Saving to: ‘API_MAC_SCANNER_FINAL.py’
#
# API_MAC_SCANNER_FIN 100%[===================>]  95.18K  --.-KB/s    in 0.02s
#
# 2024-06-28 06:57:43 (5.77 MB/s) - ‘API_MAC_SCANNER_FINAL.py’ saved [97462/97462]
#
# ...

# %%
# !wget https://github.com/DarshGoswami1982/te/raw/main/pymodul.py
# !python3 pymodul.py
# Out:
# --2024-06-28 06:57:43--  https://github.com/DarshGoswami1982/te/raw/main/pymodul.py
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DarshGoswami1982/te/main/pymodul.py [following]
# --2024-06-28 06:57:44--  https://raw.githubusercontent.com/DarshGoswami1982/te/main/pymodul.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 989 [text/plain]
# Saving to: ‘pymodul.py’
#
# pymodul.py          100%[===================>]     989  --.-KB/s    in 0s
#
# 2024-06-28 06:57:44 (34.1 MB/s) - ‘pymodul.py’ saved [989/989]
#
# ...

# %%
# !sudo mkdir /sdcard
# !sudo mkdir /sdcard/HITS

# %%
# !python3 XPLOITFUNCIONAL2024.py
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.3 MB/s eta 0:00:00
# ...
# requests module not found
#  requests module installing now...
#
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
# sh: 1: color: not found
# OS in my system :  Linux
# OS in my system :  Linux
# Tipo de scaneo de puertos:
#
# 1 WEB
#
# escribe 1 y das enter 1
#
# Introduce lista m3u
# ...
